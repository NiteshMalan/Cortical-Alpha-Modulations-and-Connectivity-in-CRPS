# %%
import mne.bem
import pandas
import numpy as np

# %%
dic = {
'PASC001':'14741', 
'PASC003':'14744',
'PASC005':'14926',
'PASC009':'14829',
'PASC010':'s10016a',
'PASC011':'14983',
'PASC012':'14938',
'PASC013':'14824',
'PASC014':'14785',
'PASC015':'14875',
'PASC018':'14922',
'PASC019':'14880',
'PASC020':'14995',
'PASC022':'s14919',
'PASC023':'14990',
'PASC024':'15005',
'PASC025':'15028',
'PASC027':'s15076',
'PASC029':'s15256',
'PASC030':'s15162',
'PASC033':'s15185',
'PASC034':'s15248',
'PASC035':'s15304',
'PASC037':'s15503',
'PASC038':'s15359',
'PASC039':'s15459',
'PASC040':'s15473'
}

dic = {
'PASP001':'s15363',
'PASP002':'s15508',
'PASP004':'15763',
'PASP014':'17105',
'PASP017':'15913',
'PASP019':'16850',
'PASP020':'17053',
'PASP021':'16803',
'PASP022':'16190',
'PASP023':'16408',
'PASP029':'16547',
'PASP030':'16527',
'PASP031':'16342',
'PASP033':'16883'
}

# %%
subs = list(dic.values())

# %%
subs = ['16883']

# %%
for sub in subs:
    subject_dir = '/mnt/beegfs/malann/Freesurfer/Patients/subject'+sub
    mne.bem.make_watershed_bem('sample', subjects_dir=subject_dir, overwrite=True, volume='T1', atlas=False, gcaatlas=False, preflood=None, show=False, copy=True, T1=None, brainmask='ws.mgz', verbose=None)
# Out:
# Running mri_watershed for BEM segmentation with the following parameters:
#
# Results dir = /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/bem/watershed
# Command = mri_watershed -useSRAS -surf /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/bem/watershed/sample /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/mri/T1.mgz /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/bem/watershed/ws.mgz
#
# Running subprocess: mri_watershed -useSRAS -surf /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/bem/watershed/sample /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/mri/T1.mgz /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/bem/watershed/ws.mgz
#
# Mode:          use surfaceRAS to save surface vertex positions
# Mode:          Saving out BEM surfaces
#
# *********************************************************
# The input file is /mnt/beegfs/malann/Freesurfer/Patients/subject16883/sample/mri/T1.mgz
# ...
